# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadAzan23/MuhammadAzan-23122020-ai/blob/main/Azan_lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# Federal Urdu University - Role Based AI Agent
# ============================================================

# Install Google Gemini library
# Run this once in Google Colab:
# !pip install -U google-genai


from google import genai


# ============================================================
# 1. GEMINI SETUP
# ============================================================

API_KEY = "YOUR_API_KEY"

client = genai.Client(api_key=API_KEY)

MODEL = "gemini-3.5-flash"


# ============================================================
# 2. USER ROLES
# ============================================================

ROLES = {

    "student": """
You are a Student Support Agent for Federal Urdu University.

Help students with:
- Admissions
- Departments and programs
- Courses
- Fees
- Exams
- Timetables
- Scholarships
- Attendance
- Academic procedures
- Campus information

Use simple and student-friendly language.
""",

    "faculty": """
You are a Faculty Support Agent for Federal Urdu University.

Help faculty members with:
- Courses
- Academic planning
- Examination procedures
- Attendance
- Grading
- Research
- Academic policies
- Department-related information

Use professional and clear language.
""",

    "admin": """
You are an Administrative Support Agent for Federal Urdu University.

Help administrative staff with:
- Admissions procedures
- Student records
- Documents
- University policies
- Notifications
- Administrative procedures
- Department coordination

Use formal and professional language.
""",

    "visitor": """
You are a University Information Agent for Federal Urdu University.

Help visitors with:
- University introduction
- Campuses
- Departments
- Degree programs
- Admissions information
- General facilities
- Contact and visiting information

Give concise and helpful answers.
"""
}


# ============================================================
# 3. COMPUTER SCIENCE DEPARTMENT DATA
# ============================================================

CS_DATA = {

    "department": "Computer Science",

    "sections": {

        # ----------------------------------------------------
        # BS 2
        # ----------------------------------------------------

        "BS2A": {
            "students": 50,
            "courses": [
                {
                    "course": "Quantitative Reasoning-II",
                    "professor": "Mrs. Asma Nisar"
                },
                {
                    "course": "Pakistan Studies",
                    "professor": "Mr. Waheed Murad"
                }
            ],
            "rooms": ["Room1"]
        },


        "BS2B": {
            "students": 50,
            "courses": [
                {
                    "course": "Pakistan Studies",
                    "professor": "Mr. Waheed Murad"
                },
                {
                    "course": "Fehm-e-Quran-1",
                    "professor": "Dr. Mohsin Ali"
                }
            ],
            "rooms": ["Room2"]
        },


        "BS2C": {
            "students": 50,
            "courses": [
                {
                    "course": "Quantitative Reasoning-II",
                    "professor": "Mr./Mrs./Miss. Aaa"
                },
                {
                    "course": "Digital Logic Design",
                    "professor": "Mr. Majid Iqbal"
                }
            ],
            "rooms": ["Room11"]
        },


        "BS2D": {
            "students": 50,
            "courses": [
                {
                    "course": "Object Oriented Programming",
                    "professor": "Dr. Khalid Shaikh"
                },
                {
                    "course": "Digital Logic Design",
                    "professor": "Mr. Majid Iqbal"
                }
            ],
            "rooms": ["Lab1", "Room3"]
        },


        "BS2E": {
            "students": 50,
            "courses": [
                {
                    "course": "Object Oriented Programming",
                    "professor": "Dr. Shazia Usmani"
                },
                {
                    "course": "Digital Logic Design",
                    "professor": "Miss Quratul Ain"
                }
            ],
            "rooms": ["Lab2", "Room2"]
        },


        "BS2F": {
            "students": 50,
            "courses": [
                {
                    "course": "Object Oriented Programming",
                    "professor": "Mrs. Salwa Iqbal"
                },
                {
                    "course": "Digital Logic Design",
                    "professor": "Miss Quratul Ain"
                }
            ],
            "rooms": ["Lab3", "Room2"]
        },


        # ----------------------------------------------------
        # BS 4
        # ----------------------------------------------------

        "BS4A": {
            "courses": [
                {
                    "course": "Design and Analysis of Algorithm",
                    "professor": "Mr. Sheikh Kashif Rafat"
                },
                {
                    "course": "Accounting",
                    "professor": "Mr./Mrs./Miss. Aaa"
                },
                {
                    "course": "Theory of Automata & Formal Languages",
                    "professor": "Miss Naheed Azeem"
                }
            ],
            "rooms": ["Lab4", "Library", "Room12"]
        },


        "BS4B": {
            "courses": [
                {
                    "course": "Design and Analysis of Algorithm",
                    "professor": "Dr. Syed Akhtar Raza"
                },
                {
                    "course": "Accounting",
                    "professor": "Mr./Mrs./Miss. Bbb"
                },
                {
                    "course": "Theory of Automata & Formal Languages",
                    "professor": "Mrs. Salwa Iqbal"
                }
            ],
            "rooms": ["Lab4"]
        },


        "BS4C": {
            "courses": [
                {
                    "course": "Theory of Automata & Formal Languages",
                    "professor": "Mrs. Salwa Iqbal"
                },
                {
                    "course": "Accounting",
                    "professor": "Mr./Mrs./Miss. Ccc"
                },
                {
                    "course": "Design and Analysis of Algorithm",
                    "professor": "Miss Noshaba"
                }
            ],
            "rooms": ["Room12", "Room1"]
        },


        "BS4D": {
            "courses": [
                {
                    "course": "Accounting",
                    "professor": "Mr./Mrs./Miss. Ddd"
                },
                {
                    "course": "Theory of Automata & Formal Languages",
                    "professor": "Miss Quratul Ain"
                },
                {
                    "course": "Design and Analysis of Algorithm",
                    "professor": "Mr. Muhammad Ahmed Ansari"
                }
            ],
            "rooms": ["Lab2", "Room13"]
        },


        # ----------------------------------------------------
        # BS 6
        # ----------------------------------------------------

        "BS6A": {
            "courses": [
                {
                    "course": "Compiler Construction",
                    "professor": "Miss Naheed Azeem"
                },
                {
                    "course": "Professional Practices",
                    "professor": "Mr./Mrs./Miss. Aaa"
                }
            ],
            "rooms": ["Lab2", "Room1"]
        },


        "BS6B": {
            "courses": [
                {
                    "course": "Professional Practices",
                    "professor": "Mr./Mrs./Miss. Bbb"
                },
                {
                    "course": "Compiler Construction",
                    "professor": "Miss Naheed Azeem"
                },
                {
                    "course": "Artificial Intelligence",
                    "professor": "Dr. Uzma Afzal"
                },
                {
                    "course": "Natural Language Processing",
                    "professor": "Dr. Muhammad Sarim"
                }
            ],
            "rooms": ["Hall"]
        },


        "BS6C": {
            "courses": [
                {
                    "course": "Natural Language Processing",
                    "professor": "Miss Quratul Ain"
                },
                {
                    "course": "Compiler Construction",
                    "professor": "Mr. Sheikh Kashif Rafat"
                },
                {
                    "course": "Artificial Intelligence",
                    "professor": "Dr. Uzma Afzal"
                },
                {
                    "course": "Professional Practices",
                    "professor": "Mr./Mrs./Miss. Ccc"
                }
            ],
            "rooms": ["Room3", "Lab1"]
        },


        "BS6D": {
            "courses": [
                {
                    "course": "Natural Language Processing",
                    "professor": "Mr. Muhammad Ahmed Ansari"
                },
                {
                    "course": "Professional Practices",
                    "professor": "Mr./Mrs./Miss. Ddd"
                },
                {
                    "course": "Compiler Construction",
                    "professor": "Mr. Sheikh Kashif Rafat"
                }
            ],
            "rooms": ["Library", "Room12"]
        },


        # ----------------------------------------------------
        # BS 7
        # ----------------------------------------------------

        "BS7": {
            "courses": [
                {
                    "course": "Grid and Cloud Computing",
                    "professor": "Dr. Uzma Afzal"
                },
                {
                    "course": "Parallel and Distributed Computing",
                    "professor": "Dr. Muhammad Sarim"
                },
                {
                    "course": "Entrepreneurship",
                    "professor": "Mr./Mrs./Miss. Aaa"
                },
                {
                    "course": "Data Science",
                    "professor": "Dr. Syed Akhtar Raza"
                }
            ],
            "rooms": ["Room13", "Lab3"]
        },


        # ----------------------------------------------------
        # BS 8
        # ----------------------------------------------------

        "BS8A": {
            "courses": []
        },

        "BS8B": {
            "courses": []
        },

        "BS8C": {
            "courses": []
        }
    }
}


# ============================================================
# 4. AGENT FUNCTION
# ============================================================

def university_agent(role, user_question):

    # Check role
    if role not in ROLES:
        return "Invalid role. Please select student, faculty, admin, or visitor."


    # Create prompt
    prompt = f"""
You are a role-based AI support agent for
Federal Urdu University.

==================================================
USER ROLE
==================================================

{role}


==================================================
ROLE INSTRUCTIONS
==================================================

{ROLES[role]}


==================================================
COMPUTER SCIENCE DEPARTMENT DATA
==================================================

{CS_DATA}


==================================================
IMPORTANT RULES
==================================================

1. Answer according to the user's role.

2. Use the provided Computer Science department
   data when the question is related to:
   - Courses
   - Professors
   - Sections
   - Students
   - Rooms
   - Department information

3. Do NOT invent professors.

4. Do NOT invent courses.

5. Do NOT invent rooms.

6. Do NOT invent class schedules.

7. The provided timetable data does not contain
   reliable day/time mapping in this format.
   Therefore, do not guess the day or time.

8. If requested information is not available,
   clearly say:
   "This information is not available in the
   current department data."

9. Keep answers simple and easy to understand.

10. If the question is about official university
    policies, fees, admissions dates, or other
    information not provided in the data, tell the
    user to verify it from the official university
    source.

11. If possible, mention the relevant section
    when answering course or professor questions.


==================================================
USER QUESTION
==================================================

{user_question}


==================================================
ANSWER
==================================================
"""


    # Send request to Gemini
    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )


    return response.text


# ============================================================
# 5. MAIN PROGRAM
# ============================================================

print("\n==============================================")
print("🎓 Federal Urdu University AI Agent")
print("==============================================")

print("\nAvailable Roles:")
print("1. student")
print("2. faculty")
print("3. admin")
print("4. visitor")

print("\nType 'exit' at any time to stop.")


while True:

    # Get role
    role = input("\nEnter your role: ").strip().lower()


    # Exit
    if role == "exit":
        print("\nGoodbye! 👋")
        break


    # Validate role
    if role not in ROLES:

        print(
            "\n❌ Invalid role."
            "\nPlease select: student, faculty, admin, or visitor."
        )

        continue


    # Get question
    user_question = input("\nYour question: ").strip()


    # Empty question
    if not user_question:

        print("\nPlease enter a question.")

        continue


    # Generate answer
    try:

        answer = university_agent(
            role,
            user_question
        )


        print("\n🤖 Agent:")
        print("----------------------------------------------")
        print(answer)
        print("----------------------------------------------")


    except Exception as e:

        print("\n❌ Error:")
        print(e)
# Out:
# ...
# 🎓 Federal Urdu University Role-Based Agent
# Available roles: student, faculty, admin, visitor
# Type 'exit' to stop.
#
# Enter your role: student
# Your question: what is the timetabel for tomorrow classes in computer science
# WARNING:google_genai.models:Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# 🤖 Agent:
# ### Tomorrow's Computer Science Class Timetable
#
# Hello! As an AI Student Support Agent, I do not have direct access to the real-time daily timetables or sudden schedule changes for individual classes.
#
# To get the most accurate and updated timetable for your classes tomorrow, please use the following official channels:
#
# ...
