# %%
# !pip install -U google-genai

from google import genai

# Add your Gemini API key
client = genai.Client(api_key="")

print("Gemini Chatbot (type 'exit' to quit)\n")

while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit", "bye"]:
        print("Chatbot: Goodbye 👋")
        break

    response = client.models.generate_content(
        model="gemini-3.6-flash",
        contents=user_input
    )

    print("Chatbot:", response.text)
# Out:
# ...
# Gemini Chatbot (type 'exit' to quit)
#
# You: exit
# Chatbot: Goodbye 👋

# %%
# !pip install -U google-genai
from google import genai

client = genai.Client(api_key="")


MODEL = "models/gemini-3.5-flash"


def travel_agent(user_input):

    prompt = f"""
You are a professional travel agent for Pakistan tourism.

Provide a well-structured travel plan with clear headings:

1. Destination Overview
2. Budget Travel Options (Bus, Train, Flight with approx cost in PKR)
3. Places to Visit (specific locations)
4. Food Suggestions (local dishes)
5. Money-Saving Tips

Make response detailed but easy for students.

User request: {user_input}

Travel Plan:
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text



print("Gemini Travel Agent Started (type 'exit' to stop)\n")

while True:
    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye ")
        break

    try:
        reply = travel_agent(user)
        print("\nAgent:\n", reply, "\n")

    except Exception as e:
        print("Error:", e)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.0/260.0 kB 22.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.49.0
#     Uninstalling google-auth-2.49.0:
#       Successfully uninstalled google-auth-2.49.0
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 2.12.1
#     Uninstalling google-genai-2.12.1:
#       Successfully uninstalled google-genai-2.12.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.57.1 which is incompatible.
# ...
# Gemini Travel Agent Started (type 'exit' to stop)
#
# You: hi
# ...

# %%
from google import genai

client = genai.Client(api_key="")

MODEL = "models/gemini-3.5-flash"


def restaurant_agent(user_input):

    prompt = f"""
You are a professional Restaurant Recommendation Agent for Pakistan.

Based on the user's preferences, recommend the best restaurant.

Consider:
- Favorite cuisine
- Occasion
- Budget
- Dietary restrictions

Use the following recommendation levels:
- Highly Recommended
- Recommended
- Maybe
- Not Recommended

Provide your answer with these headings:

1. Restaurant Name
2. Cuisine
3. Approximate Budget (PKR)
4. Best For (Family, Friends, Date, Business, etc.)
5. Recommendation
6. Reason

Examples of Pakistani restaurants include:
- Monal
- Kolachi
- Bundu Khan
- BBQ Tonight
- Salt'n Pepper
- Kababjees
- Ginsoy
- China Town
- Cafe Aylanto
- Chaaye Khana

User Request:
{user_input}
"""

    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )

    return response.text


print("Pakistan Restaurant Recommendation Agent")
print("Type 'exit' to stop.\n")

while True:

    user = input("You: ")

    if user.lower() == "exit":
        print("Goodbye!")
        break

    try:
        reply = restaurant_agent(user)
        print("\nAgent:\n")
        print(reply)
        print()

    except Exception as e:
        print("Error:", e)
# Out:
# Pakistan Restaurant Recommendation Agent
# Type 'exit' to stop.
#
# You: hi
#
# Agent:
#
# Hello! I am your professional Restaurant Recommendation Agent for Pakistan. I am here to help you find the perfect dining spot.
#
# To help me give you the absolute best recommendation tailored to your taste, please share a few details with me:
# 1. **Your City** (e.g., Karachi, Lahore, Islamabad, etc.)
# 2. **Favorite Cuisine** (e.g., Pakistani BBQ, Chinese, Italian, Continental, Desi)
# 3. **Occasion** (e.g., Family dinner, Date night, Casual hangout, Business lunch, Birthday)
# 4. **Budget** (e.g., Low, Medium, High / PKR range per person)
# 5. **Dietary Restrictions** (e.g., Vegetarian, Gluten-free, none)
#
# ---
#
# While you think about those, here is a showcase of one of Pakistan's most famous dining destinations to show you how I can help:
#
# ### 1. Restaurant Name
# **The Monal (Islamabad)**
#
# ### 2. Cuisine
# Pakistani, Traditional BBQ, and Continental
#
# ...
